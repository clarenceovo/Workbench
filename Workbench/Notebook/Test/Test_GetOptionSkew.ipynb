# %%
from Workbench.CryptoDataConnector.BinanceDataCollector import BinanceDataCollector
from Workbench.CryptoDataConnector.OKXDataCollector import OKXDataCollector
from Workbench.CryptoDataConnector.BybitDataCollector import BybitDataCollector


bn_client = BinanceDataCollector()

data = bn_client.get_option_chain()

# %%
data
# Out:
# [{'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '40185',
#     'maxPrice': '58988.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-55000-C',
#   'side': 'CALL',
#   'strikePrice': '55000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25070.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-55000-P',
#   'side': 'PUT',
#   'strikePrice': '55000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '65140',
#     'maxPrice': '83943.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-30000-C',
#   'side': 'CALL',
#   'strikePrice': '30000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25077.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-30000-P',
#   'side': 'PUT',
#   'strikePrice': '30000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '25225',
#     'maxPrice': '44030.3',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-70000-C',
#   'side': 'CALL',
#   'strikePrice': '70000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25006.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-70000-P',
#   'side': 'PUT',
#   'strikePrice': '70000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '55155',
#     'maxPrice': '73960.3',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-40000-C',
#   'side': 'CALL',
#   'strikePrice': '40000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25077.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-40000-P',
#   'side': 'PUT',
#   'strikePrice': '40000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24980',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-140000-C',
#   'side': 'CALL',
#   'strikePrice': '140000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '25885',
#     'maxPrice': '44690.4',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-140000-P',
#   'side': 'PUT',
#   'strikePrice': '140000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '20235',
#     'maxPrice': '39039.4',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-75000-C',
#   'side': 'CALL',
#   'strikePrice': '75000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24988.3',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-75000-P',
#   'side': 'PUT',
#   'strikePrice': '75000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '20402',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-110000-C',
#   'side': 'CALL',
#   'strikePrice': '110000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '15573.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-110000-P',
#   'side': 'PUT',
#   'strikePrice': '110000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '45175',
#     'maxPrice': '63977.8',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-50000-C',
#   'side': 'CALL',
#   'strikePrice': '50000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25075.9',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-50000-P',
#   'side': 'PUT',
#   'strikePrice': '50000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '15008.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-100000-C',
#   'side': 'CALL',
#   'strikePrice': '100000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '21478.2',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-100000-P',
#   'side': 'PUT',
#   'strikePrice': '100000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5380',
#     'maxPrice': '24183.6',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-90000-C',
#   'side': 'CALL',
#   'strikePrice': '90000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24297.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-90000-P',
#   'side': 'PUT',
#   'strikePrice': '90000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '35200',
#     'maxPrice': '54004.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-60000-C',
#   'side': 'CALL',
#   'strikePrice': '60000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25046.4',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-60000-P',
#   'side': 'PUT',
#   'strikePrice': '60000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '20922.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-110000-C',
#   'side': 'CALL',
#   'strikePrice': '110000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '30469.6',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-110000-P',
#   'side': 'PUT',
#   'strikePrice': '110000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '26029.9',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-100000-C',
#   'side': 'CALL',
#   'strikePrice': '100000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24157.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-100000-P',
#   'side': 'PUT',
#   'strikePrice': '100000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '41295',
#     'maxPrice': '60099.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-55000-C',
#   'side': 'CALL',
#   'strikePrice': '55000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24891.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-55000-P',
#   'side': 'PUT',
#   'strikePrice': '55000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '36485',
#     'maxPrice': '55288',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-60000-C',
#   'side': 'CALL',
#   'strikePrice': '60000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24802.3',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-60000-P',
#   'side': 'PUT',
#   'strikePrice': '60000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '22241.6',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-130000-C',
#   'side': 'CALL',
#   'strikePrice': '130000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '18070',
#     'maxPrice': '36873.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-80000-C',
#   'side': 'CALL',
#   'strikePrice': '80000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '17215',
#     'maxPrice': '36468',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-130000-P',
#   'side': 'PUT',
#   'strikePrice': '130000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24561',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-180000-C',
#   'side': 'CALL',
#   'strikePrice': '180000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '23931.9',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-80000-P',
#   'side': 'PUT',
#   'strikePrice': '80000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '22440',
#     'maxPrice': '41243.3',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-75000-C',
#   'side': 'CALL',
#   'strikePrice': '75000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '63270',
#     'maxPrice': '82077.5',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-180000-P',
#   'side': 'PUT',
#   'strikePrice': '180000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24245.2',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-75000-P',
#   'side': 'PUT',
#   'strikePrice': '75000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '65655',
#     'maxPrice': '84458.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-30000-C',
#   'side': 'CALL',
#   'strikePrice': '30000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25058.6',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-30000-P',
#   'side': 'PUT',
#   'strikePrice': '30000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '55870',
#     'maxPrice': '74674.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-40000-C',
#   'side': 'CALL',
#   'strikePrice': '40000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25028.4',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-40000-P',
#   'side': 'PUT',
#   'strikePrice': '40000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24860.2',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-130000-C',
#   'side': 'CALL',
#   'strikePrice': '130000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '15920',
#     'maxPrice': '34723.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-130000-P',
#   'side': 'PUT',
#   'strikePrice': '130000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25076.2',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-200000-C',
#   'side': 'CALL',
#   'strikePrice': '200000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '85765',
#     'maxPrice': '104571.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-200000-P',
#   'side': 'PUT',
#   'strikePrice': '200000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24777.3',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-200000-C',
#   'side': 'CALL',
#   'strikePrice': '200000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25073.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-180000-C',
#   'side': 'CALL',
#   'strikePrice': '180000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24954.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-240000-C',
#   'side': 'CALL',
#   'strikePrice': '240000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '82765',
#     'maxPrice': '101571.4',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-200000-P',
#   'side': 'PUT',
#   'strikePrice': '200000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1751011200000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '65800',
#     'maxPrice': '84606.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250627-180000-P',
#   'side': 'PUT',
#   'strikePrice': '180000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1758873600000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '121930',
#     'maxPrice': '140732.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250926-240000-P',
#   'side': 'PUT',
#   'strikePrice': '240000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24091.4',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-115000-C',
#   'side': 'CALL',
#   'strikePrice': '115000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '38090',
#     'maxPrice': '56895.6',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-60000-C',
#   'side': 'CALL',
#   'strikePrice': '60000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24858.2',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-60000-P',
#   'side': 'PUT',
#   'strikePrice': '60000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '36748.6',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-115000-P',
#   'side': 'PUT',
#   'strikePrice': '115000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '56680',
#     'maxPrice': '75485.5',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-40000-C',
#   'side': 'CALL',
#   'strikePrice': '40000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24543.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-220000-C',
#   'side': 'CALL',
#   'strikePrice': '220000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '23400.8',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-130000-C',
#   'side': 'CALL',
#   'strikePrice': '130000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24053.2',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-180000-C',
#   'side': 'CALL',
#   'strikePrice': '180000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '17535',
#     'maxPrice': '36337.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-85000-C',
#   'side': 'CALL',
#   'strikePrice': '85000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25037.8',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-40000-P',
#   'side': 'PUT',
#   'strikePrice': '40000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '99530',
#     'maxPrice': '118333',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-220000-P',
#   'side': 'PUT',
#   'strikePrice': '220000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '14995',
#     'maxPrice': '41888.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-130000-P',
#   'side': 'PUT',
#   'strikePrice': '130000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '61995',
#     'maxPrice': '80799',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-180000-P',
#   'side': 'PUT',
#   'strikePrice': '180000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1766736000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '9565',
#     'maxPrice': '31449.2',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-251226-95000-C',
#   'side': 'CALL',
#   'strikePrice': '95000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
# ...
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '12195.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-107000-P',
#   'side': 'PUT',
#   'strikePrice': '107000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24171.1',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-103000-P',
#   'side': 'PUT',
#   'strikePrice': '103000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '15915.3',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-111000-P',
#   'side': 'PUT',
#   'strikePrice': '111000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '17938',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-105000-P',
#   'side': 'PUT',
#   'strikePrice': '105000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '21890.3',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-104000-P',
#   'side': 'PUT',
#   'strikePrice': '104000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '14936.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-110000-P',
#   'side': 'PUT',
#   'strikePrice': '110000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '14117.6',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-100000-C',
#   'side': 'CALL',
#   'strikePrice': '100000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24796.7',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-114000-C',
#   'side': 'CALL',
#   'strikePrice': '114000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25002.9',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-109000-C',
#   'side': 'CALL',
#   'strikePrice': '109000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24173',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-100000-P',
#   'side': 'PUT',
#   'strikePrice': '100000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '95',
#     'maxPrice': '18898',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-114000-P',
#   'side': 'PUT',
#   'strikePrice': '114000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '13974.4',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-109000-P',
#   'side': 'PUT',
#   'strikePrice': '109000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '16025.2',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-98000-C',
#   'side': 'CALL',
#   'strikePrice': '98000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24384.8',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-106000-C',
#   'side': 'CALL',
#   'strikePrice': '106000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24630.3',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-112000-C',
#   'side': 'CALL',
#   'strikePrice': '112000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '24712.5',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-113000-C',
#   'side': 'CALL',
#   'strikePrice': '113000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '12337.5',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-102000-C',
#   'side': 'CALL',
#   'strikePrice': '102000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '23767.4',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-98000-P',
#   'side': 'PUT',
#   'strikePrice': '98000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '13611.6',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-106000-P',
#   'side': 'PUT',
#   'strikePrice': '106000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '17902.4',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-113000-P',
#   'side': 'PUT',
#   'strikePrice': '113000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '16905.8',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-112000-P',
#   'side': 'PUT',
#   'strikePrice': '112000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'},
#  {'expiryDate': 1750320000000,
#   'filters': [{'filterType': 'PRICE_FILTER',
#     'minPrice': '5',
#     'maxPrice': '25159',
#     'tickSize': '5.0'},
#    {'filterType': 'LOT_SIZE',
#     'minQty': '0.01',
#     'maxQty': '200',
#     'stepSize': '0.01'}],
#   'symbol': 'BTC-250619-102000-P',
#   'side': 'PUT',
#   'strikePrice': '102000.00000000',
#   'underlying': 'BTCUSDT',
#   'unit': 1,
#   'makerFeeRate': '0.00030000',
#   'takerFeeRate': '0.00030000',
#   'liquidationFeeRate': '0.00190000',
#   'minQty': '0.01',
#   'maxQty': '200',
#   'initialMargin': '0.15000000',
#   'maintenanceMargin': '0.07500000',
#   'minInitialMargin': '0.10000000',
#   'minMaintenanceMargin': '0.05000000',
#   'priceScale': 1,
#   'quantityScale': 2,
#   'quoteAsset': 'USDT'}]

# %%
option = bn_client.get_option_by_symbol(data[0])
# Out:
# Error fetching data for BTC-250627-55000-C: 400 Client Error: Bad Request for url: https://eapi.binance.com/eapi/v1/openInterest?symbol=BTC-250627-55000-C
